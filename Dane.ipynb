# %% [markdown]
# <a href="https://colab.research.google.com/github/JSzczpin/Kurs/blob/main/Dane.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Wprowadzenie do Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
x = np.linspace(0,20,100)
y = np.random.randn(100,4)
y = np.cumsum(y, axis=0)

# %%
plt.plot(x,y)
# Out:
# [<matplotlib.lines.Line2D at 0x7f38d29e7d30>,
#  <matplotlib.lines.Line2D at 0x7f38d2993dd8>,
#  <matplotlib.lines.Line2D at 0x7f38d2993f60>,
#  <matplotlib.lines.Line2D at 0x7f38d29a0128>]

# %%
sns.set()
plt.plot(x,y)
# Out:
# [<matplotlib.lines.Line2D at 0x7f38d29d6390>,
#  <matplotlib.lines.Line2D at 0x7f38d29d64e0>,
#  <matplotlib.lines.Line2D at 0x7f38d29d6668>,
#  <matplotlib.lines.Line2D at 0x7f38d29d67f0>]

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe(include=['category'])
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %%
sns.relplot(data = df,x='total_bill',y='tip',hue='size',size='size',sizes=(10,200),palette='viridis',
            style='size')

# %%
sns.set(style='whitegrid',palette='deep',font_scale=1.2)

# %%
sns.relplot(data = df,x='total_bill',y='tip',hue='size',size='size',sizes=(10,200),palette='viridis',
            col='time')

# %%
sns.relplot(data = df,x='total_bill',y='tip',hue='size',size='size',sizes=(10,200),palette='viridis',
            col='time',row='smoker')
